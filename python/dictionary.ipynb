# %%
person = {"name": "Ali", "age": 18, "phone": 123456}

# %% [markdown]
# # Check if Key Exist

# %%
print(person.get("name"))
# Out:
# Ali

# %%
print(person.get("sex"))
# Out:
# None

# %% [markdown]
# # Get All Keys

# %%
print(person.keys())
# Out:
# dict_keys(['name', 'age', 'phone'])

# %% [markdown]
# # Get All Values

# %%
print(person.values())
# Out:
# dict_values(['Ali', 18, 123456])

# %% [markdown]
# # Get Both Keys & Values

# %%
print(person.items())
# Out:
# dict_items([('name', 'Ali'), ('age', 18), ('phone', 123456)])

# %% [markdown]
# # Add a New Key Value Pair

# %%
person["sex"] = "male"
print(person)
# Out:
# {'name': 'Ali', 'age': 18, 'phone': 123456, 'sex': 'male'}

# %% [markdown]
# # Loop a Dict

# %%
for key, value in person.items():
    print(key, value)
# Out:
# name Ali
# age 18
# phone 123456
# sex male

# %% [markdown]
# # Sort a Dict Based on Value

# %%
from collections import OrderedDict
from operator import getitem
d = {"Apple" : {"Colour" : "Red", "Count" : 23},
    "Grape" : {"Colour" : "Purple", "Count" : 11}, 
    "Melon" : {"Colour" : "Green", "Count" : 34}}
d_mark_sort = OrderedDict(sorted(d.items(), key = lambda x: getitem(x[1], "Count")))
print(d_mark_sort)
# Out:
# OrderedDict([('Grape', {'Colour': 'Purple', 'Count': 11}), ('Apple', {'Colour': 'Red', 'Count': 23}), ('Melon', {'Colour': 'Green', 'Count': 34})])
